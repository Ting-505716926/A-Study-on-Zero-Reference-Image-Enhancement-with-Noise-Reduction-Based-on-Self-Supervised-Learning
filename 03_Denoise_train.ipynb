# %%
import cv2
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.optimizers import Adam

# %%
from denoise_model import denoising_net
from utils.training_process import training_process

# %% [markdown]
# # Config

# %%
Lambda1 = 1
Lambda2 = 2
epochs = 1000
batch_size = 16
# 各模型極限batch size(3080Ti-12GB)： 10 , 20, 7, 
model_name = 'Small_Denoised_sigmoid_LOL_Lambda2_2_guassion25'
add_noise = True
lr = 1e-4
# input_shape = (512,512,3)
model_path = './model/'

mode = ['Large', 'Small']
mode = mode[0]

# %% [markdown]
# # Load Data

# %%
def process(image):
    image = tf.cast(image/255. ,tf.float32)
    return image

def process2(image, image2):
    image = tf.cast(image/255. ,tf.float32)
    image2 = tf.cast(image2/255. ,tf.float32)
    return image, image2

# %%
train_path = './Dataset/denoise/train/'
# train_path = './Dataset/train/'
validation_path = './Dataset/denoise/train_label/'

trainset = image_dataset_from_directory(train_path,
                                        labels=None,
                                        label_mode=None,
                                        color_mode='rgb',
                                        class_names=None,
                                        image_size=(256,256),
                                        batch_size=batch_size,
                                        crop_to_aspect_ratio=True)

valset = image_dataset_from_directory(train_path,
                                      seed=1,
                                      labels=None,
                                      label_mode=None,
                                      color_mode='rgb',
                                      class_names=None,
                                      image_size=(256,256),
                                      batch_size=batch_size,
                                      crop_to_aspect_ratio=True)

val_label = image_dataset_from_directory(train_path,
                                        seed=1,
                                        labels=None,
                                        label_mode=None,
                                        color_mode='rgb',
                                        class_names=None,
                                        image_size=(256,256),
                                        batch_size=batch_size,
                                        crop_to_aspect_ratio=True)

valset = tf.data.Dataset.zip((valset, val_label))
valset = valset.map(process2)
trainset = trainset.map(process)
# Out:
# Found 485 files belonging to 1 classes.
# Found 485 files belonging to 1 classes.
# Found 485 files belonging to 1 classes.

# %%
iterators = len(trainset)

# %% [markdown]
# # Build Model

# %%
model = denoising_net(input_shape=(None,None,3),
                        add_noise=add_noise,
                        model_name=model_name,
                        Lambda1=Lambda1,
                        Lambda2=Lambda2,
                        mode=mode)
model.denoising_net.summary()
# model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_27 (Conv2D)             (None, None, None,   1344        ['input_3[0][0]']
#                                 48)
#
#  leaky_re_lu_26 (LeakyReLU)     (None, None, None,   0           ['conv2d_27[0][0]']
#                                 48)
#
#  batch_normalization_25 (BatchN  (None, None, None,   192        ['leaky_re_lu_26[0][0]']
#  ormalization)                  48)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, None, None,   0          ['batch_normalization_25[0][0]']
#                                 48)
#
#  conv2d_28 (Conv2D)             (None, None, None,   20784       ['max_pooling2d_5[0][0]']
#                                 48)
#
#  leaky_re_lu_27 (LeakyReLU)     (None, None, None,   0           ['conv2d_28[0][0]']
#                                 48)
#
#  batch_normalization_26 (BatchN  (None, None, None,   192        ['leaky_re_lu_27[0][0]']
#  ormalization)                  48)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, None, None,   0          ['batch_normalization_26[0][0]']
#                                 48)
#
#  conv2d_29 (Conv2D)             (None, None, None,   20784       ['max_pooling2d_6[0][0]']
#                                 48)
#
#  leaky_re_lu_28 (LeakyReLU)     (None, None, None,   0           ['conv2d_29[0][0]']
#                                 48)
#
#  batch_normalization_27 (BatchN  (None, None, None,   192        ['leaky_re_lu_28[0][0]']
#  ormalization)                  48)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, None, None,   0          ['batch_normalization_27[0][0]']
#                                 48)
#
#  conv2d_30 (Conv2D)             (None, None, None,   20784       ['max_pooling2d_7[0][0]']
#                                 48)
#
#  leaky_re_lu_29 (LeakyReLU)     (None, None, None,   0           ['conv2d_30[0][0]']
#                                 48)
#
#  batch_normalization_28 (BatchN  (None, None, None,   192        ['leaky_re_lu_29[0][0]']
#  ormalization)                  48)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, None, None,   0          ['batch_normalization_28[0][0]']
#                                 48)
#
#  conv2d_31 (Conv2D)             (None, None, None,   20784       ['max_pooling2d_8[0][0]']
#                                 48)
#
#  leaky_re_lu_30 (LeakyReLU)     (None, None, None,   0           ['conv2d_31[0][0]']
#                                 48)
#
#  batch_normalization_29 (BatchN  (None, None, None,   192        ['leaky_re_lu_30[0][0]']
#  ormalization)                  48)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, None, None,   0          ['batch_normalization_29[0][0]']
#                                 48)
#
#  conv2d_32 (Conv2D)             (None, None, None,   20784       ['max_pooling2d_9[0][0]']
#                                 48)
#
#  leaky_re_lu_31 (LeakyReLU)     (None, None, None,   0           ['conv2d_32[0][0]']
#                                 48)
#
#  batch_normalization_30 (BatchN  (None, None, None,   192        ['leaky_re_lu_31[0][0]']
#  ormalization)                  48)
#
#  tf.compat.v1.shape_11 (TFOpLam  (4,)                0           ['max_pooling2d_8[0][0]']
#  bda)
#
#  tf.compat.v1.shape_12 (TFOpLam  (4,)                0           ['max_pooling2d_8[0][0]']
#  bda)
#
#  conv2d_transpose_5 (Conv2DTran  (None, None, None,   9264       ['batch_normalization_30[0][0]']
#  spose)                         48)
#
#  tf.__operators__.getitem_10 (S  ()                  0           ['tf.compat.v1.shape_11[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_11 (S  ()                  0           ['tf.compat.v1.shape_12[0][0]']
#  licingOpLambda)
#
#  tf.image.resize_5 (TFOpLambda)  (None, None, None,   0          ['conv2d_transpose_5[0][0]',
#                                 48)                               'tf.__operators__.getitem_10[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_11[0][
#                                                                  0]']
#
#  concatenate_9 (Concatenate)    (None, None, None,   0           ['tf.image.resize_5[0][0]',
#                                 96)                               'max_pooling2d_8[0][0]']
#
#  conv2d_33 (Conv2D)             (None, None, None,   83040       ['concatenate_9[0][0]']
#                                 96)
#
#  leaky_re_lu_32 (LeakyReLU)     (None, None, None,   0           ['conv2d_33[0][0]']
#                                 96)
#
#  batch_normalization_31 (BatchN  (None, None, None,   384        ['leaky_re_lu_32[0][0]']
#  ormalization)                  96)
#
#  conv2d_34 (Conv2D)             (None, None, None,   83040       ['batch_normalization_31[0][0]']
#                                 96)
#
#  leaky_re_lu_33 (LeakyReLU)     (None, None, None,   0           ['conv2d_34[0][0]']
#                                 96)
#
#  batch_normalization_32 (BatchN  (None, None, None,   384        ['leaky_re_lu_33[0][0]']
#  ormalization)                  96)
#
#  tf.compat.v1.shape_13 (TFOpLam  (4,)                0           ['max_pooling2d_7[0][0]']
#  bda)
#
#  tf.compat.v1.shape_14 (TFOpLam  (4,)                0           ['max_pooling2d_7[0][0]']
#  bda)
#
#  conv2d_transpose_6 (Conv2DTran  (None, None, None,   36960      ['batch_normalization_32[0][0]']
#  spose)                         96)
#
#  tf.__operators__.getitem_12 (S  ()                  0           ['tf.compat.v1.shape_13[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_13 (S  ()                  0           ['tf.compat.v1.shape_14[0][0]']
#  licingOpLambda)
#
#  tf.image.resize_6 (TFOpLambda)  (None, None, None,   0          ['conv2d_transpose_6[0][0]',
#                                 96)                               'tf.__operators__.getitem_12[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_13[0][
#                                                                  0]']
#
#  concatenate_10 (Concatenate)   (None, None, None,   0           ['tf.image.resize_6[0][0]',
#                                 144)                              'max_pooling2d_7[0][0]']
#
#  conv2d_35 (Conv2D)             (None, None, None,   124512      ['concatenate_10[0][0]']
#                                 96)
#
#  leaky_re_lu_34 (LeakyReLU)     (None, None, None,   0           ['conv2d_35[0][0]']
#                                 96)
#
#  batch_normalization_33 (BatchN  (None, None, None,   384        ['leaky_re_lu_34[0][0]']
#  ormalization)                  96)
#
#  conv2d_36 (Conv2D)             (None, None, None,   83040       ['batch_normalization_33[0][0]']
#                                 96)
#
#  leaky_re_lu_35 (LeakyReLU)     (None, None, None,   0           ['conv2d_36[0][0]']
#                                 96)
#
#  batch_normalization_34 (BatchN  (None, None, None,   384        ['leaky_re_lu_35[0][0]']
#  ormalization)                  96)
#
#  tf.compat.v1.shape_15 (TFOpLam  (4,)                0           ['max_pooling2d_6[0][0]']
#  bda)
#
#  tf.compat.v1.shape_16 (TFOpLam  (4,)                0           ['max_pooling2d_6[0][0]']
#  bda)
#
#  conv2d_transpose_7 (Conv2DTran  (None, None, None,   36960      ['batch_normalization_34[0][0]']
#  spose)                         96)
#
#  tf.__operators__.getitem_14 (S  ()                  0           ['tf.compat.v1.shape_15[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_15 (S  ()                  0           ['tf.compat.v1.shape_16[0][0]']
#  licingOpLambda)
#
#  tf.image.resize_7 (TFOpLambda)  (None, None, None,   0          ['conv2d_transpose_7[0][0]',
#                                 96)                               'tf.__operators__.getitem_14[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_15[0][
#                                                                  0]']
#
#  concatenate_11 (Concatenate)   (None, None, None,   0           ['tf.image.resize_7[0][0]',
#                                 144)                              'max_pooling2d_6[0][0]']
#
#  conv2d_37 (Conv2D)             (None, None, None,   124512      ['concatenate_11[0][0]']
#                                 96)
#
#  leaky_re_lu_36 (LeakyReLU)     (None, None, None,   0           ['conv2d_37[0][0]']
#                                 96)
#
#  batch_normalization_35 (BatchN  (None, None, None,   384        ['leaky_re_lu_36[0][0]']
#  ormalization)                  96)
#
#  conv2d_38 (Conv2D)             (None, None, None,   83040       ['batch_normalization_35[0][0]']
#                                 96)
#
#  leaky_re_lu_37 (LeakyReLU)     (None, None, None,   0           ['conv2d_38[0][0]']
#                                 96)
#
#  batch_normalization_36 (BatchN  (None, None, None,   384        ['leaky_re_lu_37[0][0]']
#  ormalization)                  96)
#
#  tf.compat.v1.shape_17 (TFOpLam  (4,)                0           ['max_pooling2d_5[0][0]']
#  bda)
#
#  tf.compat.v1.shape_18 (TFOpLam  (4,)                0           ['max_pooling2d_5[0][0]']
#  bda)
#
#  conv2d_transpose_8 (Conv2DTran  (None, None, None,   36960      ['batch_normalization_36[0][0]']
#  spose)                         96)
#
#  tf.__operators__.getitem_16 (S  ()                  0           ['tf.compat.v1.shape_17[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_17 (S  ()                  0           ['tf.compat.v1.shape_18[0][0]']
#  licingOpLambda)
#
#  tf.image.resize_8 (TFOpLambda)  (None, None, None,   0          ['conv2d_transpose_8[0][0]',
#                                 96)                               'tf.__operators__.getitem_16[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_17[0][
#                                                                  0]']
#
#  concatenate_12 (Concatenate)   (None, None, None,   0           ['tf.image.resize_8[0][0]',
#                                 144)                              'max_pooling2d_5[0][0]']
#
#  conv2d_39 (Conv2D)             (None, None, None,   124512      ['concatenate_12[0][0]']
#                                 96)
#
#  leaky_re_lu_38 (LeakyReLU)     (None, None, None,   0           ['conv2d_39[0][0]']
#                                 96)
#
#  batch_normalization_37 (BatchN  (None, None, None,   384        ['leaky_re_lu_38[0][0]']
#  ormalization)                  96)
#
#  conv2d_40 (Conv2D)             (None, None, None,   83040       ['batch_normalization_37[0][0]']
#                                 96)
#
#  leaky_re_lu_39 (LeakyReLU)     (None, None, None,   0           ['conv2d_40[0][0]']
#                                 96)
#
#  batch_normalization_38 (BatchN  (None, None, None,   384        ['leaky_re_lu_39[0][0]']
#  ormalization)                  96)
#
#  tf.compat.v1.shape_19 (TFOpLam  (4,)                0           ['input_3[0][0]']
#  bda)
#
#  tf.compat.v1.shape_20 (TFOpLam  (4,)                0           ['input_3[0][0]']
#  bda)
#
#  conv2d_transpose_9 (Conv2DTran  (None, None, None,   36960      ['batch_normalization_38[0][0]']
#  spose)                         96)
#
#  tf.__operators__.getitem_18 (S  ()                  0           ['tf.compat.v1.shape_19[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_19 (S  ()                  0           ['tf.compat.v1.shape_20[0][0]']
#  licingOpLambda)
#
#  tf.image.resize_9 (TFOpLambda)  (None, None, None,   0          ['conv2d_transpose_9[0][0]',
#                                 96)                               'tf.__operators__.getitem_18[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_19[0][
#                                                                  0]']
#
#  concatenate_13 (Concatenate)   (None, None, None,   0           ['tf.image.resize_9[0][0]',
#                                 99)                               'input_3[0][0]']
#
#  conv2d_41 (Conv2D)             (None, None, None,   85632       ['concatenate_13[0][0]']
#                                 96)
#
#  leaky_re_lu_40 (LeakyReLU)     (None, None, None,   0           ['conv2d_41[0][0]']
#                                 96)
#
#  batch_normalization_39 (BatchN  (None, None, None,   384        ['leaky_re_lu_40[0][0]']
#  ormalization)                  96)
#
#  conv2d_42 (Conv2D)             (None, None, None,   83040       ['batch_normalization_39[0][0]']
#                                 96)
#
#  leaky_re_lu_41 (LeakyReLU)     (None, None, None,   0           ['conv2d_42[0][0]']
#                                 96)
#
#  batch_normalization_40 (BatchN  (None, None, None,   384        ['leaky_re_lu_41[0][0]']
#  ormalization)                  96)
#
#  conv2d_43 (Conv2D)             (None, None, None,   9312        ['batch_normalization_40[0][0]']
#                                 96)
#
#  leaky_re_lu_42 (LeakyReLU)     (None, None, None,   0           ['conv2d_43[0][0]']
#                                 96)
#
#  batch_normalization_41 (BatchN  (None, None, None,   384        ['leaky_re_lu_42[0][0]']
#  ormalization)                  96)
#
#  conv2d_44 (Conv2D)             (None, None, None,   9312        ['batch_normalization_41[0][0]']
#                                 96)
#
#  leaky_re_lu_43 (LeakyReLU)     (None, None, None,   0           ['conv2d_44[0][0]']
#                                 96)
#
#  batch_normalization_42 (BatchN  (None, None, None,   384        ['leaky_re_lu_43[0][0]']
#  ormalization)                  96)
#
#  conv2d_45 (Conv2D)             (None, None, None,   291         ['batch_normalization_42[0][0]']
#                                 3)
#
#  activation (Activation)        (None, None, None,   0           ['conv2d_45[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 1,244,451
# Trainable params: 1,241,571
# Non-trainable params: 2,880
# __________________________________________________________________________________________________

# %% [markdown]
# # Compile

# %%
ratio = epochs / 100

def lr_callable(ratio, epoch, gamma=0.5):
    print()
    if epoch == int(20 * ratio) -1:
        new_lr = model.optimizer.learning_rate * gamma
        model.optimizer.learning_rate = new_lr
        print('upgard lr!!!')
    elif epoch == int(40 * ratio) -1:
        new_lr = model.optimizer.learning_rate * gamma
        model.optimizer.learning_rate = new_lr
        print('upgard lr!!!')
    elif epoch == int(60 * ratio) -1:
        new_lr = model.optimizer.learning_rate * gamma
        model.optimizer.learning_rate = new_lr
        print('upgard lr!!!')
    elif epoch == int(80 * ratio) -1:
        new_lr = model.optimizer.learning_rate * gamma
        model.optimizer.learning_rate = new_lr
        print('upgard lr!!!')
        
model.compile(optimizer=Adam(learning_rate=lr, clipvalue=1.0))

# %% [markdown]
# # Trianing

# %%
best_ssim = 0
best_psnr = 0
for epoch in range(epochs):
    if epoch != 0:
        print()
    print('Epoch:{0}/{1}'.format(epoch+1,epochs))
    
    strat = time.time()
    # 預設最多會有10個評估參數
    mean_loss = np.zeros(10)
    
    # Iterate over the batches of the dataset.
    for step, x_batch_train in enumerate(trainset):
        # 呼叫訓練
        dict = model.train_step(x_batch_train, epoch, epochs)  
        
        # 輸出訓練過程(Epoch、step、time、total loss等參數)
        mean_loss = training_process(step, mean_loss, dict, len(trainset), strat, mode=1)  
    training_process(step, mean_loss, dict, len(trainset), strat, mode=2)

    lr_callable(ratio, epoch, gamma=0.5)
    
    mean_ssim = 0
    mean_psnr = 0
    for val, label in valset:
        ssim, psnr = model.validation_step(val, label)
        mean_ssim += ssim
        mean_psnr += psnr
    mean_ssim /= len(valset)
    mean_psnr /= len(valset)
    
    print()
    
    if mean_ssim > best_ssim and mean_psnr > best_psnr:
        best_ssim = mean_ssim
        best_psnr = mean_psnr
        model.denoising_net.save_weights(model_path + model_name +\
             '/weights/epoch{0}_ssim{1:6f}_psnr{2:6f}/'.format(epoch+1, best_ssim, best_psnr))
        print('save_model', end=' ')
        print('ssim: {0:6f} - psnr: {1:6f}'.format(best_ssim, best_psnr))
    else:
        print('ssim: {0:6f} - psnr: {1:6f}'.format(mean_ssim, mean_psnr))
# Out:
# Epoch:1/1000
# 31/31 [████████████████████] 7.24s  - train_loss:0.087435 - l_rec1:0.087086 - l_rec2:0.000174
#
# save_model ssim: 0.336793 - psnr: 11.904207
#
# Epoch:2/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.070142 - l_rec1:0.069585 - l_rec2:0.000278
#
# save_model ssim: 0.348873 - psnr: 13.319426
#
# Epoch:3/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.050046 - l_rec1:0.049453 - l_rec2:0.000297
#
# save_model ssim: 0.357869 - psnr: 14.803411
#
# Epoch:4/1000
# 31/31 [████████████████████] 4.69s  - train_loss:0.046262 - l_rec1:0.045534 - l_rec2:0.000364
#
# save_model ssim: 0.360669 - psnr: 15.010697
#
# Epoch:5/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.043397 - l_rec1:0.042546 - l_rec2:0.000425
#
# save_model ssim: 0.361939 - psnr: 15.020649
#
# Epoch:6/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.043541 - l_rec1:0.042520 - l_rec2:0.000510
#
# save_model ssim: 0.369406 - psnr: 15.177604
#
# Epoch:7/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.045057 - l_rec1:0.043830 - l_rec2:0.000614
#
# save_model ssim: 0.388452 - psnr: 15.581940
#
# Epoch:8/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.039237 - l_rec1:0.038020 - l_rec2:0.000608
#
# save_model ssim: 0.455740 - psnr: 17.692083
#
# Epoch:9/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.023391 - l_rec1:0.022572 - l_rec2:0.000410
#
# save_model ssim: 0.553788 - psnr: 21.819277
#
# Epoch:10/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.021425 - l_rec1:0.020590 - l_rec2:0.000418
#
# save_model ssim: 0.565070 - psnr: 22.433313
#
# Epoch:11/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.019058 - l_rec1:0.018240 - l_rec2:0.000409
#
# save_model ssim: 0.570727 - psnr: 22.822567
#
# Epoch:12/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.017813 - l_rec1:0.016979 - l_rec2:0.000417
#
# save_model ssim: 0.575741 - psnr: 23.063837
#
# Epoch:13/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.018276 - l_rec1:0.017356 - l_rec2:0.000460
#
# ssim: 0.574662 - psnr: 23.161390
#
# Epoch:14/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.018872 - l_rec1:0.017852 - l_rec2:0.000510
#
# save_model ssim: 0.581311 - psnr: 23.322079
#
# Epoch:15/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.020097 - l_rec1:0.018947 - l_rec2:0.000575
#
# save_model ssim: 0.583382 - psnr: 23.451584
#
# Epoch:16/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.020051 - l_rec1:0.018821 - l_rec2:0.000615
#
# ssim: 0.575375 - psnr: 23.404173
#
# Epoch:17/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.018007 - l_rec1:0.016833 - l_rec2:0.000587
#
# save_model ssim: 0.592877 - psnr: 23.623697
#
# Epoch:18/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.017791 - l_rec1:0.016576 - l_rec2:0.000608
#
# ssim: 0.586834 - psnr: 23.658743
#
# Epoch:19/1000
# 31/31 [████████████████████] 4.65s  - train_loss:0.016803 - l_rec1:0.015593 - l_rec2:0.000605
#
# save_model ssim: 0.593295 - psnr: 23.980145
#
# Epoch:20/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.018835 - l_rec1:0.017411 - l_rec2:0.000712
#
# ssim: 0.592428 - psnr: 24.109869
#
# Epoch:21/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.019876 - l_rec1:0.018317 - l_rec2:0.000780
#
# save_model ssim: 0.601026 - psnr: 24.614702
#
# Epoch:22/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.018819 - l_rec1:0.017272 - l_rec2:0.000774
#
# ssim: 0.598312 - psnr: 24.891552
#
# Epoch:23/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.015774 - l_rec1:0.014408 - l_rec2:0.000683
#
# ssim: 0.600580 - psnr: 25.270378
#
# Epoch:24/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.017945 - l_rec1:0.016339 - l_rec2:0.000803
#
# ssim: 0.596129 - psnr: 25.289433
#
# Epoch:25/1000
# 31/31 [████████████████████] 4.70s  - train_loss:0.017405 - l_rec1:0.015785 - l_rec2:0.000810
#
# ssim: 0.599219 - psnr: 25.384315
#
# Epoch:26/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.015458 - l_rec1:0.013946 - l_rec2:0.000756
#
# save_model ssim: 0.601695 - psnr: 25.581827
#
# Epoch:27/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.018115 - l_rec1:0.016314 - l_rec2:0.000900
#
# ssim: 0.594874 - psnr: 25.247452
#
# Epoch:28/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.019718 - l_rec1:0.017685 - l_rec2:0.001016
#
# save_model ssim: 0.603302 - psnr: 25.628468
#
# Epoch:29/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.018576 - l_rec1:0.016573 - l_rec2:0.001001
#
# ssim: 0.601062 - psnr: 25.537035
#
# Epoch:30/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.021357 - l_rec1:0.019042 - l_rec2:0.001158
#
# save_model ssim: 0.621877 - psnr: 26.004236
#
# Epoch:31/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.019858 - l_rec1:0.017620 - l_rec2:0.001119
#
# ssim: 0.604770 - psnr: 25.669724
#
# Epoch:32/1000
# 31/31 [████████████████████] 4.67s  - train_loss:0.017957 - l_rec1:0.015875 - l_rec2:0.001041
#
# ssim: 0.611909 - psnr: 25.847549
#
# Epoch:33/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.014201 - l_rec1:0.012502 - l_rec2:0.000850
#
# ssim: 0.607345 - psnr: 25.802565
#
# Epoch:34/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.017565 - l_rec1:0.015423 - l_rec2:0.001071
#
# ssim: 0.618925 - psnr: 26.029644
#
# Epoch:35/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.017990 - l_rec1:0.015736 - l_rec2:0.001127
#
# ssim: 0.609291 - psnr: 25.847616
#
# Epoch:36/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.015484 - l_rec1:0.013452 - l_rec2:0.001016
#
# save_model ssim: 0.623069 - psnr: 26.175428
#
# Epoch:37/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.019296 - l_rec1:0.016729 - l_rec2:0.001283
#
# save_model ssim: 0.628839 - psnr: 26.276087
#
# Epoch:38/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.017991 - l_rec1:0.015563 - l_rec2:0.001214
#
# ssim: 0.621367 - psnr: 26.138165
#
# Epoch:39/1000
# 31/31 [████████████████████] 4.68s  - train_loss:0.019416 - l_rec1:0.016677 - l_rec2:0.001369
#
# save_model ssim: 0.630932 - psnr: 26.398794
#
# Epoch:40/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.018459 - l_rec1:0.015844 - l_rec2:0.001308
#
# ssim: 0.623620 - psnr: 26.235556
#
# Epoch:41/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.018165 - l_rec1:0.015522 - l_rec2:0.001322
#
# ssim: 0.630421 - psnr: 26.422867
#
# Epoch:42/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.015528 - l_rec1:0.013201 - l_rec2:0.001163
#
# ssim: 0.604998 - psnr: 25.954762
#
# Epoch:43/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.016027 - l_rec1:0.013600 - l_rec2:0.001214
#
# ssim: 0.624397 - psnr: 26.347788
#
# Epoch:44/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.017183 - l_rec1:0.014531 - l_rec2:0.001326
#
# ssim: 0.625151 - psnr: 26.367868
#
# Epoch:45/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.016548 - l_rec1:0.013964 - l_rec2:0.001292
#
# ssim: 0.609274 - psnr: 26.064434
#
# Epoch:46/1000
# 31/31 [████████████████████] 4.68s  - train_loss:0.016821 - l_rec1:0.014101 - l_rec2:0.001360
#
# ssim: 0.621227 - psnr: 26.404009
#
# Epoch:47/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.019287 - l_rec1:0.016181 - l_rec2:0.001553
#
# ssim: 0.627264 - psnr: 26.598291
#
# Epoch:48/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.017893 - l_rec1:0.014907 - l_rec2:0.001493
#
# ssim: 0.628815 - psnr: 26.625143
#
# Epoch:49/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.018857 - l_rec1:0.015678 - l_rec2:0.001590
#
# save_model ssim: 0.632937 - psnr: 26.821547
#
# Epoch:50/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.018277 - l_rec1:0.015129 - l_rec2:0.001574
#
# ssim: 0.621465 - psnr: 26.567545
#
# Epoch:51/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.014119 - l_rec1:0.011637 - l_rec2:0.001241
#
# ssim: 0.630262 - psnr: 26.838417
#
# Epoch:52/1000
# 31/31 [████████████████████] 4.69s  - train_loss:0.018497 - l_rec1:0.015251 - l_rec2:0.001623
#
# ssim: 0.627919 - psnr: 26.752487
#
# Epoch:53/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.017043 - l_rec1:0.013914 - l_rec2:0.001565
#
# ssim: 0.610869 - psnr: 26.405972
#
# Epoch:54/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.022427 - l_rec1:0.018403 - l_rec2:0.002012
#
# ssim: 0.616560 - psnr: 26.496723
#
# Epoch:55/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.016740 - l_rec1:0.013601 - l_rec2:0.001569
#
# ssim: 0.616939 - psnr: 26.571236
#
# Epoch:56/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.019699 - l_rec1:0.015959 - l_rec2:0.001870
#
# ssim: 0.620897 - psnr: 26.677658
#
# Epoch:57/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.015960 - l_rec1:0.012892 - l_rec2:0.001534
#
# ssim: 0.627226 - psnr: 26.833059
#
# Epoch:58/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.015174 - l_rec1:0.012211 - l_rec2:0.001481
#
# save_model ssim: 0.635586 - psnr: 26.971134
#
# Epoch:59/1000
# 31/31 [████████████████████] 4.70s  - train_loss:0.019739 - l_rec1:0.015900 - l_rec2:0.001920
#
# ssim: 0.615708 - psnr: 26.572306
#
# Epoch:60/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.018975 - l_rec1:0.015137 - l_rec2:0.001919
#
# ssim: 0.624747 - psnr: 26.730444
#
# Epoch:61/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.016755 - l_rec1:0.013376 - l_rec2:0.001690
#
# save_model ssim: 0.644763 - psnr: 27.231165
#
# Epoch:62/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.018783 - l_rec1:0.014905 - l_rec2:0.001939
#
# ssim: 0.618503 - psnr: 26.674635
#
# Epoch:63/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.019793 - l_rec1:0.015716 - l_rec2:0.002039
#
# ssim: 0.643448 - psnr: 27.203333
#
# Epoch:64/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.016408 - l_rec1:0.012929 - l_rec2:0.001739
#
# ssim: 0.635693 - psnr: 27.046612
#
# Epoch:65/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.020386 - l_rec1:0.016082 - l_rec2:0.002152
#
# ssim: 0.625463 - psnr: 26.790821
#
# Epoch:66/1000
# 31/31 [████████████████████] 4.69s  - train_loss:0.019340 - l_rec1:0.015208 - l_rec2:0.002066
#
# ssim: 0.623009 - psnr: 26.761400
#
# Epoch:67/1000
# 31/31 [████████████████████] 4.65s  - train_loss:0.019672 - l_rec1:0.015366 - l_rec2:0.002153
#
# ssim: 0.617793 - psnr: 26.651354
#
# Epoch:68/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.019517 - l_rec1:0.015258 - l_rec2:0.002129
#
# ssim: 0.621975 - psnr: 26.660189
#
# Epoch:69/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.021310 - l_rec1:0.016617 - l_rec2:0.002346
#
# ssim: 0.640884 - psnr: 27.170876
#
# Epoch:70/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.018157 - l_rec1:0.014104 - l_rec2:0.002026
#
# save_model ssim: 0.646324 - psnr: 27.294094
#
# Epoch:71/1000
# 31/31 [████████████████████] 4.67s  - train_loss:0.019865 - l_rec1:0.015371 - l_rec2:0.002247
#
# ssim: 0.636898 - psnr: 27.011330
#
# Epoch:72/1000
# 31/31 [████████████████████] 4.53s  - train_loss:0.022220 - l_rec1:0.017126 - l_rec2:0.002547
#
# ssim: 0.624130 - psnr: 26.731468
#
# Epoch:73/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.020065 - l_rec1:0.015323 - l_rec2:0.002371
#
# ssim: 0.627046 - psnr: 26.851254
#
# Epoch:74/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.018031 - l_rec1:0.013706 - l_rec2:0.002162
#
# ssim: 0.606313 - psnr: 26.405315
#
# Epoch:75/1000
# 31/31 [████████████████████] 4.68s  - train_loss:0.018384 - l_rec1:0.013949 - l_rec2:0.002217
#
# ssim: 0.632383 - psnr: 26.962778
#
# Epoch:76/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.019127 - l_rec1:0.014480 - l_rec2:0.002324
#
# ssim: 0.628077 - psnr: 26.877493
#
# Epoch:77/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.019427 - l_rec1:0.014640 - l_rec2:0.002394
#
# ssim: 0.621006 - psnr: 26.766520
#
# Epoch:78/1000
# 31/31 [████████████████████] 4.65s  - train_loss:0.021882 - l_rec1:0.016475 - l_rec2:0.002704
#
# ssim: 0.621862 - psnr: 26.725197
#
# Epoch:79/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.019398 - l_rec1:0.014686 - l_rec2:0.002356
#
# ssim: 0.626687 - psnr: 26.869455
#
# Epoch:80/1000
# 31/31 [████████████████████] 4.70s  - train_loss:0.019256 - l_rec1:0.014411 - l_rec2:0.002422
#
# ssim: 0.643553 - psnr: 27.310240
#
# Epoch:81/1000
# 31/31 [████████████████████] 4.54s  - train_loss:0.019201 - l_rec1:0.014330 - l_rec2:0.002436
#
# ssim: 0.623678 - psnr: 26.893116
#
# Epoch:82/1000
# 31/31 [████████████████████] 4.54s  - train_loss:0.019139 - l_rec1:0.014237 - l_rec2:0.002451
#
# ssim: 0.627336 - psnr: 26.912212
#
# Epoch:83/1000
# 31/31 [████████████████████] 4.48s  - train_loss:0.022694 - l_rec1:0.016907 - l_rec2:0.002894
#
# ssim: 0.628293 - psnr: 26.866695
#
# Epoch:84/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.017616 - l_rec1:0.012970 - l_rec2:0.002323
#
# ssim: 0.636519 - psnr: 27.092642
#
# Epoch:85/1000
# 31/31 [████████████████████] 4.43s  - train_loss:0.019731 - l_rec1:0.014497 - l_rec2:0.002617
#
# ssim: 0.639698 - psnr: 27.188520
#
# Epoch:86/1000
# 31/31 [████████████████████] 4.42s  - train_loss:0.019538 - l_rec1:0.014296 - l_rec2:0.002621
#
# ssim: 0.638525 - psnr: 27.168785
#
# Epoch:87/1000
# 31/31 [████████████████████] 4.49s  - train_loss:0.020593 - l_rec1:0.015107 - l_rec2:0.002743
#
# ssim: 0.623067 - psnr: 26.849550
#
# Epoch:88/1000
# 31/31 [████████████████████] 4.40s  - train_loss:0.017784 - l_rec1:0.013030 - l_rec2:0.002377
#
# ssim: 0.636150 - psnr: 27.190273
#
# Epoch:89/1000
# 31/31 [████████████████████] 4.40s  - train_loss:0.020060 - l_rec1:0.014609 - l_rec2:0.002726
#
# save_model ssim: 0.651386 - psnr: 27.422832
#
# Epoch:90/1000
# 31/31 [████████████████████] 4.50s  - train_loss:0.024003 - l_rec1:0.017489 - l_rec2:0.003257
#
# ssim: 0.640120 - psnr: 27.260551
#
# Epoch:91/1000
# 31/31 [████████████████████] 4.41s  - train_loss:0.020697 - l_rec1:0.015054 - l_rec2:0.002822
#
# ssim: 0.638694 - psnr: 27.204321
#
# Epoch:92/1000
# 31/31 [████████████████████] 4.51s  - train_loss:0.020352 - l_rec1:0.014711 - l_rec2:0.002821
#
# ssim: 0.626814 - psnr: 26.952942
#
# Epoch:93/1000
# 31/31 [████████████████████] 4.48s  - train_loss:0.019664 - l_rec1:0.014135 - l_rec2:0.002764
#
# ssim: 0.629607 - psnr: 26.997849
#
# Epoch:94/1000
# 31/31 [████████████████████] 4.53s  - train_loss:0.017410 - l_rec1:0.012413 - l_rec2:0.002499
#
# ssim: 0.636084 - psnr: 27.203058
#
# Epoch:95/1000
# 31/31 [████████████████████] 4.52s  - train_loss:0.019530 - l_rec1:0.014035 - l_rec2:0.002747
#
# ssim: 0.632349 - psnr: 27.021145
#
# Epoch:96/1000
# 31/31 [████████████████████] 4.50s  - train_loss:0.018137 - l_rec1:0.012937 - l_rec2:0.002600
#
# ssim: 0.626990 - psnr: 26.959501
#
# Epoch:97/1000
# 31/31 [████████████████████] 4.44s  - train_loss:0.020292 - l_rec1:0.014345 - l_rec2:0.002973
#
# ssim: 0.630497 - psnr: 27.006128
#
# Epoch:98/1000
# 31/31 [████████████████████] 4.47s  - train_loss:0.024111 - l_rec1:0.017045 - l_rec2:0.003533
#
# ssim: 0.614419 - psnr: 26.738779
#
# Epoch:99/1000
# 31/31 [████████████████████] 4.53s  - train_loss:0.023465 - l_rec1:0.016580 - l_rec2:0.003443
#
# ssim: 0.633487 - psnr: 27.133068
#
# Epoch:100/1000
# 31/31 [████████████████████] 4.53s  - train_loss:0.023284 - l_rec1:0.016468 - l_rec2:0.003408
#
# ssim: 0.636339 - psnr: 27.168413
#
# Epoch:101/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.019111 - l_rec1:0.013412 - l_rec2:0.002849
#
# ssim: 0.646283 - psnr: 27.357595
#
# Epoch:102/1000
# 31/31 [████████████████████] 4.54s  - train_loss:0.019896 - l_rec1:0.013938 - l_rec2:0.002979
#
# ssim: 0.642080 - psnr: 27.315731
#
# Epoch:103/1000
# 31/31 [████████████████████] 4.40s  - train_loss:0.020365 - l_rec1:0.014302 - l_rec2:0.003032
#
# ssim: 0.642018 - psnr: 27.258373
#
# Epoch:104/1000
# 31/31 [████████████████████] 4.43s  - train_loss:0.023610 - l_rec1:0.016389 - l_rec2:0.003611
#
# ssim: 0.637092 - psnr: 27.080860
#
# Epoch:105/1000
# 31/31 [████████████████████] 4.44s  - train_loss:0.020801 - l_rec1:0.014239 - l_rec2:0.003281
#
# ssim: 0.634856 - psnr: 27.153786
#
# Epoch:106/1000
# 31/31 [████████████████████] 4.42s  - train_loss:0.018381 - l_rec1:0.012718 - l_rec2:0.002832
#
# ssim: 0.623572 - psnr: 26.893246
#
# Epoch:107/1000
# 31/31 [████████████████████] 4.43s  - train_loss:0.020025 - l_rec1:0.013788 - l_rec2:0.003118
#
# ssim: 0.642576 - psnr: 27.401134
#
# Epoch:108/1000
# 31/31 [████████████████████] 4.53s  - train_loss:0.021925 - l_rec1:0.015032 - l_rec2:0.003446
#
# ssim: 0.644855 - psnr: 27.407654
#
# Epoch:109/1000
# 31/31 [████████████████████] 4.44s  - train_loss:0.023555 - l_rec1:0.016062 - l_rec2:0.003746
#
# ssim: 0.628016 - psnr: 26.986065
#
# Epoch:110/1000
# 31/31 [████████████████████] 4.42s  - train_loss:0.022207 - l_rec1:0.015094 - l_rec2:0.003556
#
# ssim: 0.629730 - psnr: 26.999546
#
# Epoch:111/1000
# 31/31 [████████████████████] 4.41s  - train_loss:0.018566 - l_rec1:0.012515 - l_rec2:0.003026
#
# save_model ssim: 0.657971 - psnr: 27.702995
#
# Epoch:112/1000
# 31/31 [████████████████████] 4.48s  - train_loss:0.020270 - l_rec1:0.013776 - l_rec2:0.003247
#
# ssim: 0.635627 - psnr: 27.199535
#
# Epoch:113/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.019902 - l_rec1:0.013645 - l_rec2:0.003128
#
# ssim: 0.640753 - psnr: 27.329523
#
# Epoch:114/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.019517 - l_rec1:0.013157 - l_rec2:0.003180
#
# ssim: 0.632910 - psnr: 27.145468
#
# Epoch:115/1000
# 31/31 [████████████████████] 4.73s  - train_loss:0.020444 - l_rec1:0.013763 - l_rec2:0.003341
#
# ssim: 0.644136 - psnr: 27.349482
#
# Epoch:116/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.021102 - l_rec1:0.014201 - l_rec2:0.003450
#
# ssim: 0.647385 - psnr: 27.410505
#
# Epoch:117/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.022239 - l_rec1:0.014872 - l_rec2:0.003684
#
# ssim: 0.611090 - psnr: 26.673376
#
# Epoch:118/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.013194 - l_rec1:0.008676 - l_rec2:0.002259
#
# ssim: 0.627247 - psnr: 27.071695
#
# Epoch:119/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.023484 - l_rec1:0.015653 - l_rec2:0.003916
#
# ssim: 0.605824 - psnr: 26.612368
#
# Epoch:120/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.020257 - l_rec1:0.013569 - l_rec2:0.003344
#
# ssim: 0.630930 - psnr: 27.156858
#
# Epoch:121/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.018912 - l_rec1:0.012425 - l_rec2:0.003244
#
# ssim: 0.632301 - psnr: 27.154390
#
# Epoch:122/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.024219 - l_rec1:0.015964 - l_rec2:0.004127
#
# ssim: 0.637606 - psnr: 27.247240
#
# Epoch:123/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.021083 - l_rec1:0.013906 - l_rec2:0.003589
#
# ssim: 0.632078 - psnr: 27.157120
#
# Epoch:124/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.023916 - l_rec1:0.015905 - l_rec2:0.004006
#
# ssim: 0.611521 - psnr: 26.692999
#
# Epoch:125/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.024132 - l_rec1:0.015750 - l_rec2:0.004191
#
# ssim: 0.614061 - psnr: 26.697596
#
# Epoch:126/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.022754 - l_rec1:0.014925 - l_rec2:0.003915
#
# ssim: 0.645547 - psnr: 27.454510
#
# Epoch:127/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.018824 - l_rec1:0.012319 - l_rec2:0.003253
#
# save_model ssim: 0.665333 - psnr: 27.933094
#
# Epoch:128/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.021893 - l_rec1:0.014259 - l_rec2:0.003817
#
# ssim: 0.651807 - psnr: 27.576902
#
# Epoch:129/1000
# 31/31 [████████████████████] 4.85s  - train_loss:0.026229 - l_rec1:0.017026 - l_rec2:0.004601
#
# ssim: 0.639311 - psnr: 27.332050
#
# Epoch:130/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.024245 - l_rec1:0.015715 - l_rec2:0.004265
#
# ssim: 0.654005 - psnr: 27.603619
#
# Epoch:131/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.015184 - l_rec1:0.009585 - l_rec2:0.002799
#
# ssim: 0.648157 - psnr: 27.482357
#
# Epoch:132/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.023627 - l_rec1:0.015131 - l_rec2:0.004248
#
# ssim: 0.645758 - psnr: 27.470333
#
# Epoch:133/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.025565 - l_rec1:0.016472 - l_rec2:0.004546
#
# ssim: 0.638116 - psnr: 27.335455
#
# Epoch:134/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.023818 - l_rec1:0.015418 - l_rec2:0.004200
#
# ssim: 0.645232 - psnr: 27.431660
#
# Epoch:135/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.021568 - l_rec1:0.013732 - l_rec2:0.003918
#
# ssim: 0.634837 - psnr: 27.170187
#
# Epoch:136/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.024161 - l_rec1:0.015470 - l_rec2:0.004346
#
# ssim: 0.647362 - psnr: 27.534317
#
# Epoch:137/1000
# 31/31 [████████████████████] 4.67s  - train_loss:0.023090 - l_rec1:0.014602 - l_rec2:0.004244
#
# ssim: 0.614204 - psnr: 26.785807
#
# Epoch:138/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.024163 - l_rec1:0.015182 - l_rec2:0.004491
#
# ssim: 0.626088 - psnr: 26.940828
#
# Epoch:139/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.021445 - l_rec1:0.013578 - l_rec2:0.003933
#
# ssim: 0.635271 - psnr: 27.261530
#
# Epoch:140/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.023779 - l_rec1:0.014926 - l_rec2:0.004427
#
# ssim: 0.652216 - psnr: 27.587284
#
# Epoch:141/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.025934 - l_rec1:0.016336 - l_rec2:0.004799
#
# ssim: 0.632317 - psnr: 27.133848
#
# Epoch:142/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.024257 - l_rec1:0.015032 - l_rec2:0.004612
#
# ssim: 0.625391 - psnr: 26.989744
#
# Epoch:143/1000
# 31/31 [████████████████████] 4.73s  - train_loss:0.021263 - l_rec1:0.013199 - l_rec2:0.004032
#
# ssim: 0.655036 - psnr: 27.598837
#
# Epoch:144/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.025302 - l_rec1:0.015727 - l_rec2:0.004788
#
# ssim: 0.641744 - psnr: 27.327955
#
# Epoch:145/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.017274 - l_rec1:0.010738 - l_rec2:0.003268
#
# ssim: 0.626204 - psnr: 27.098007
#
# Epoch:146/1000
# 31/31 [████████████████████] 4.54s  - train_loss:0.024151 - l_rec1:0.014724 - l_rec2:0.004713
#
# ssim: 0.643406 - psnr: 27.334604
#
# Epoch:147/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.022777 - l_rec1:0.014041 - l_rec2:0.004368
#
# ssim: 0.666858 - psnr: 27.906878
#
# Epoch:148/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.021842 - l_rec1:0.013536 - l_rec2:0.004153
#
# ssim: 0.651039 - psnr: 27.598190
#
# Epoch:149/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.023537 - l_rec1:0.014194 - l_rec2:0.004671
#
# ssim: 0.649124 - psnr: 27.536324
#
# Epoch:150/1000
# 31/31 [████████████████████] 4.68s  - train_loss:0.021358 - l_rec1:0.013035 - l_rec2:0.004161
#
# ssim: 0.653979 - psnr: 27.716785
#
# Epoch:151/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.021944 - l_rec1:0.013381 - l_rec2:0.004281
#
# ssim: 0.646787 - psnr: 27.536369
#
# Epoch:152/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.024925 - l_rec1:0.015220 - l_rec2:0.004853
#
# ssim: 0.614255 - psnr: 26.725965
#
# Epoch:153/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.021855 - l_rec1:0.013455 - l_rec2:0.004200
#
# ssim: 0.649088 - psnr: 27.530830
#
# Epoch:154/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.026817 - l_rec1:0.016203 - l_rec2:0.005307
#
# ssim: 0.627996 - psnr: 27.079857
#
# Epoch:155/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.026277 - l_rec1:0.016073 - l_rec2:0.005102
#
# ssim: 0.631583 - psnr: 27.147905
#
# Epoch:156/1000
# 31/31 [████████████████████] 4.65s  - train_loss:0.025266 - l_rec1:0.015107 - l_rec2:0.005079
#
# ssim: 0.632723 - psnr: 27.218946
#
# Epoch:157/1000
# 31/31 [████████████████████] 4.70s  - train_loss:0.023545 - l_rec1:0.014071 - l_rec2:0.004737
#
# ssim: 0.657275 - psnr: 27.732401
#
# Epoch:158/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.023445 - l_rec1:0.014219 - l_rec2:0.004613
#
# ssim: 0.640528 - psnr: 27.346773
#
# Epoch:159/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.024098 - l_rec1:0.014374 - l_rec2:0.004862
#
# ssim: 0.639815 - psnr: 27.258503
#
# Epoch:160/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.023552 - l_rec1:0.013954 - l_rec2:0.004799
#
# ssim: 0.636167 - psnr: 27.194317
#
# Epoch:161/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.023802 - l_rec1:0.014276 - l_rec2:0.004763
#
# ssim: 0.608845 - psnr: 26.660803
#
# Epoch:162/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.024767 - l_rec1:0.014618 - l_rec2:0.005074
#
# ssim: 0.639841 - psnr: 27.338955
#
# Epoch:163/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.024190 - l_rec1:0.014297 - l_rec2:0.004947
#
# ssim: 0.640148 - psnr: 27.371803
#
# Epoch:164/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.022206 - l_rec1:0.013150 - l_rec2:0.004528
#
# ssim: 0.623186 - psnr: 27.053432
#
# Epoch:165/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.026550 - l_rec1:0.015558 - l_rec2:0.005496
#
# ssim: 0.663361 - psnr: 27.884954
#
# Epoch:166/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.026001 - l_rec1:0.015399 - l_rec2:0.005301
#
# ssim: 0.640716 - psnr: 27.388556
#
# Epoch:167/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.020191 - l_rec1:0.011927 - l_rec2:0.004132
#
# ssim: 0.657111 - psnr: 27.815235
#
# Epoch:168/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.025869 - l_rec1:0.015157 - l_rec2:0.005356
#
# ssim: 0.646784 - psnr: 27.417276
#
# Epoch:169/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.024668 - l_rec1:0.014262 - l_rec2:0.005203
#
# ssim: 0.636309 - psnr: 27.297329
#
# Epoch:170/1000
# 31/31 [████████████████████] 4.73s  - train_loss:0.026886 - l_rec1:0.015654 - l_rec2:0.005616
#
# ssim: 0.618585 - psnr: 26.924833
#
# Epoch:171/1000
# 31/31 [████████████████████] 4.65s  - train_loss:0.028665 - l_rec1:0.016697 - l_rec2:0.005984
#
# ssim: 0.639931 - psnr: 27.377312
#
# Epoch:172/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.023141 - l_rec1:0.013039 - l_rec2:0.005051
#
# ssim: 0.633253 - psnr: 27.178993
#
# Epoch:173/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.021856 - l_rec1:0.012711 - l_rec2:0.004573
#
# ssim: 0.656964 - psnr: 27.610350
#
# Epoch:174/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.027049 - l_rec1:0.015679 - l_rec2:0.005685
#
# ssim: 0.660269 - psnr: 27.798803
#
# Epoch:175/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.025541 - l_rec1:0.014675 - l_rec2:0.005433
#
# ssim: 0.640083 - psnr: 27.387325
#
# Epoch:176/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.027416 - l_rec1:0.015721 - l_rec2:0.005848
#
# ssim: 0.625102 - psnr: 27.106976
#
# Epoch:177/1000
# 31/31 [████████████████████] 4.67s  - train_loss:0.028303 - l_rec1:0.015987 - l_rec2:0.006158
#
# save_model ssim: 0.671697 - psnr: 28.052282
#
# Epoch:178/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.024672 - l_rec1:0.014189 - l_rec2:0.005242
#
# ssim: 0.640307 - psnr: 27.417610
#
# Epoch:179/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.024383 - l_rec1:0.013884 - l_rec2:0.005250
#
# ssim: 0.657295 - psnr: 27.705011
#
# Epoch:180/1000
# 31/31 [████████████████████] 4.71s  - train_loss:0.020627 - l_rec1:0.011692 - l_rec2:0.004467
#
# ssim: 0.653057 - psnr: 27.602163
#
# Epoch:181/1000
# 31/31 [████████████████████] 4.74s  - train_loss:0.026838 - l_rec1:0.015364 - l_rec2:0.005737
#
# ssim: 0.619160 - psnr: 26.975237
#
# Epoch:182/1000
# 31/31 [████████████████████] 4.71s  - train_loss:0.024629 - l_rec1:0.013876 - l_rec2:0.005376
#
# ssim: 0.648016 - psnr: 27.384792
#
# Epoch:183/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.023980 - l_rec1:0.013484 - l_rec2:0.005248
#
# ssim: 0.648964 - psnr: 27.559172
#
# Epoch:184/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.028339 - l_rec1:0.015885 - l_rec2:0.006227
#
# ssim: 0.661962 - psnr: 27.839329
#
# Epoch:185/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.029288 - l_rec1:0.016392 - l_rec2:0.006448
#
# ssim: 0.658206 - psnr: 27.792952
#
# Epoch:186/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.030987 - l_rec1:0.017312 - l_rec2:0.006838
#
# ssim: 0.637282 - psnr: 27.293959
#
# Epoch:187/1000
# 31/31 [████████████████████] 4.72s  - train_loss:0.025133 - l_rec1:0.014239 - l_rec2:0.005447
#
# ssim: 0.638618 - psnr: 27.319229
#
# Epoch:188/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.030366 - l_rec1:0.016875 - l_rec2:0.006745
#
# ssim: 0.632264 - psnr: 27.164761
#
# Epoch:189/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.023648 - l_rec1:0.013162 - l_rec2:0.005243
#
# ssim: 0.644671 - psnr: 27.488937
#
# Epoch:190/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.028734 - l_rec1:0.015995 - l_rec2:0.006370
#
# ssim: 0.661274 - psnr: 27.807226
#
# Epoch:191/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.029041 - l_rec1:0.016213 - l_rec2:0.006414
#
# ssim: 0.627820 - psnr: 27.029444
#
# Epoch:192/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.024716 - l_rec1:0.013688 - l_rec2:0.005514
#
# ssim: 0.617628 - psnr: 26.855955
#
# Epoch:193/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.023954 - l_rec1:0.013278 - l_rec2:0.005338
#
# ssim: 0.628978 - psnr: 27.185844
#
# Epoch:194/1000
# 31/31 [████████████████████] 4.72s  - train_loss:0.027954 - l_rec1:0.015491 - l_rec2:0.006232
#
# ssim: 0.657231 - psnr: 27.736383
#
# Epoch:195/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.026494 - l_rec1:0.014315 - l_rec2:0.006090
#
# ssim: 0.647728 - psnr: 27.508896
#
# Epoch:196/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.020899 - l_rec1:0.011287 - l_rec2:0.004806
#
# ssim: 0.670740 - psnr: 27.984934
#
# Epoch:197/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.031724 - l_rec1:0.017048 - l_rec2:0.007338
#
# ssim: 0.651586 - psnr: 27.663301
#
# Epoch:198/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.028030 - l_rec1:0.015226 - l_rec2:0.006402
#
# save_model ssim: 0.676730 - psnr: 28.129988
#
# Epoch:199/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.029670 - l_rec1:0.016139 - l_rec2:0.006765
#
# ssim: 0.648587 - psnr: 27.553053
#
# Epoch:200/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.027414 - l_rec1:0.014660 - l_rec2:0.006377
# upgard lr!!!
#
# ssim: 0.637535 - psnr: 27.364729
#
# Epoch:201/1000
# 31/31 [████████████████████] 4.74s  - train_loss:0.033293 - l_rec1:0.017903 - l_rec2:0.007695
#
# ssim: 0.659217 - psnr: 27.810453
#
# Epoch:202/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.026658 - l_rec1:0.014526 - l_rec2:0.006066
#
# ssim: 0.648021 - psnr: 27.538645
#
# Epoch:203/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.022115 - l_rec1:0.011885 - l_rec2:0.005115
#
# ssim: 0.638420 - psnr: 27.355642
#
# Epoch:204/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.025639 - l_rec1:0.013916 - l_rec2:0.005862
#
# ssim: 0.649801 - psnr: 27.618872
#
# Epoch:205/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.028878 - l_rec1:0.015526 - l_rec2:0.006676
#
# ssim: 0.641131 - psnr: 27.436108
#
# Epoch:206/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.027474 - l_rec1:0.014791 - l_rec2:0.006341
#
# ssim: 0.632453 - psnr: 27.209700
#
# Epoch:207/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.029253 - l_rec1:0.015669 - l_rec2:0.006792
#
# ssim: 0.664678 - psnr: 27.922457
#
# Epoch:208/1000
# 31/31 [████████████████████] 4.67s  - train_loss:0.027073 - l_rec1:0.014457 - l_rec2:0.006308
#
# ssim: 0.656182 - psnr: 27.732864
#
# Epoch:209/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.030592 - l_rec1:0.016136 - l_rec2:0.007228
#
# ssim: 0.633227 - psnr: 27.183760
#
# Epoch:210/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.028010 - l_rec1:0.014816 - l_rec2:0.006597
#
# ssim: 0.633078 - psnr: 27.254578
#
# Epoch:211/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.031496 - l_rec1:0.016888 - l_rec2:0.007304
#
# ssim: 0.658856 - psnr: 27.775208
#
# Epoch:212/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.032801 - l_rec1:0.017717 - l_rec2:0.007542
#
# ssim: 0.629248 - psnr: 27.199844
#
# Epoch:213/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.026414 - l_rec1:0.013997 - l_rec2:0.006208
#
# ssim: 0.646480 - psnr: 27.583582
#
# Epoch:214/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.025958 - l_rec1:0.013710 - l_rec2:0.006124
#
# ssim: 0.656140 - psnr: 27.743357
#
# Epoch:215/1000
# 31/31 [████████████████████] 4.73s  - train_loss:0.027633 - l_rec1:0.014505 - l_rec2:0.006564
#
# ssim: 0.638613 - psnr: 27.354397
#
# Epoch:216/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.023740 - l_rec1:0.012483 - l_rec2:0.005628
#
# ssim: 0.632910 - psnr: 27.262796
#
# Epoch:217/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.029220 - l_rec1:0.015111 - l_rec2:0.007054
#
# ssim: 0.646912 - psnr: 27.560366
#
# Epoch:218/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.027157 - l_rec1:0.014038 - l_rec2:0.006560
#
# ssim: 0.652412 - psnr: 27.594530
#
# Epoch:219/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.024994 - l_rec1:0.012859 - l_rec2:0.006067
#
# ssim: 0.660676 - psnr: 27.802420
#
# Epoch:220/1000
# 31/31 [████████████████████] 4.65s  - train_loss:0.024104 - l_rec1:0.012437 - l_rec2:0.005833
#
# ssim: 0.650496 - psnr: 27.652586
#
# Epoch:221/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.032101 - l_rec1:0.016380 - l_rec2:0.007861
#
# ssim: 0.658678 - psnr: 27.809763
#
# Epoch:222/1000
# 31/31 [████████████████████] 4.70s  - train_loss:0.029040 - l_rec1:0.014992 - l_rec2:0.007024
#
# ssim: 0.658188 - psnr: 27.741409
#
# Epoch:223/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.033370 - l_rec1:0.017212 - l_rec2:0.008079
#
# ssim: 0.640543 - psnr: 27.380415
#
# Epoch:224/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.025039 - l_rec1:0.012748 - l_rec2:0.006146
#
# ssim: 0.629650 - psnr: 27.195541
#
# Epoch:225/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.029723 - l_rec1:0.015102 - l_rec2:0.007310
#
# ssim: 0.641393 - psnr: 27.410233
#
# Epoch:226/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.025643 - l_rec1:0.013019 - l_rec2:0.006312
#
# ssim: 0.630835 - psnr: 27.199129
#
# Epoch:227/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.029312 - l_rec1:0.015233 - l_rec2:0.007040
#
# ssim: 0.655736 - psnr: 27.728853
#
# Epoch:228/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.029154 - l_rec1:0.015054 - l_rec2:0.007050
#
# ssim: 0.665505 - psnr: 27.926811
#
# Epoch:229/1000
# 31/31 [████████████████████] 4.67s  - train_loss:0.027204 - l_rec1:0.013957 - l_rec2:0.006624
#
# ssim: 0.627646 - psnr: 27.134726
#
# Epoch:230/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.027096 - l_rec1:0.013871 - l_rec2:0.006613
#
# ssim: 0.647743 - psnr: 27.543652
#
# Epoch:231/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.028412 - l_rec1:0.014308 - l_rec2:0.007052
#
# ssim: 0.651847 - psnr: 27.645508
#
# Epoch:232/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.031715 - l_rec1:0.015987 - l_rec2:0.007864
#
# ssim: 0.630157 - psnr: 27.227810
#
# Epoch:233/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.030168 - l_rec1:0.015210 - l_rec2:0.007479
#
# ssim: 0.631518 - psnr: 27.185207
#
# Epoch:234/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.024807 - l_rec1:0.012531 - l_rec2:0.006138
#
# ssim: 0.631108 - psnr: 27.239750
#
# Epoch:235/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.023189 - l_rec1:0.011445 - l_rec2:0.005872
#
# ssim: 0.662723 - psnr: 27.925867
#
# Epoch:236/1000
# 31/31 [████████████████████] 4.71s  - train_loss:0.023447 - l_rec1:0.011801 - l_rec2:0.005823
#
# ssim: 0.646848 - psnr: 27.610079
#
# Epoch:237/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.025059 - l_rec1:0.012651 - l_rec2:0.006204
#
# ssim: 0.650902 - psnr: 27.646412
#
# Epoch:238/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.026949 - l_rec1:0.013495 - l_rec2:0.006727
#
# ssim: 0.634791 - psnr: 27.311871
#
# Epoch:239/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.027901 - l_rec1:0.013668 - l_rec2:0.007117
#
# ssim: 0.671545 - psnr: 28.114849
#
# Epoch:240/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.031841 - l_rec1:0.015864 - l_rec2:0.007989
#
# ssim: 0.660822 - psnr: 27.777920
#
# Epoch:241/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.026098 - l_rec1:0.013021 - l_rec2:0.006539
#
# ssim: 0.632322 - psnr: 27.251871
#
# Epoch:242/1000
# 31/31 [████████████████████] 4.54s  - train_loss:0.025147 - l_rec1:0.012264 - l_rec2:0.006441
#
# ssim: 0.631972 - psnr: 27.258139
#
# Epoch:243/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.028912 - l_rec1:0.014234 - l_rec2:0.007339
#
# ssim: 0.637195 - psnr: 27.305279
#
# Epoch:244/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.030903 - l_rec1:0.015319 - l_rec2:0.007792
#
# ssim: 0.649519 - psnr: 27.531561
#
# Epoch:245/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.030691 - l_rec1:0.015291 - l_rec2:0.007700
#
# ssim: 0.641265 - psnr: 27.393314
#
# Epoch:246/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.030929 - l_rec1:0.015475 - l_rec2:0.007727
#
# ssim: 0.665554 - psnr: 27.961843
#
# Epoch:247/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.030534 - l_rec1:0.014638 - l_rec2:0.007948
#
# ssim: 0.644174 - psnr: 27.502579
#
# Epoch:248/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.022873 - l_rec1:0.010986 - l_rec2:0.005943
#
# ssim: 0.639381 - psnr: 27.413725
#
# Epoch:249/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.027637 - l_rec1:0.013447 - l_rec2:0.007095
#
# ssim: 0.670743 - psnr: 28.108582
#
# Epoch:250/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.031377 - l_rec1:0.015403 - l_rec2:0.007987
#
# ssim: 0.632845 - psnr: 27.228712
#
# Epoch:251/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.032154 - l_rec1:0.015440 - l_rec2:0.008357
#
# ssim: 0.629015 - psnr: 27.155472
#
# Epoch:252/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.027187 - l_rec1:0.013115 - l_rec2:0.007036
#
# ssim: 0.653219 - psnr: 27.758089
#
# Epoch:253/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.026490 - l_rec1:0.012769 - l_rec2:0.006861
#
# ssim: 0.619047 - psnr: 27.033684
#
# Epoch:254/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.023335 - l_rec1:0.011477 - l_rec2:0.005929
#
# ssim: 0.642393 - psnr: 27.535925
#
# Epoch:255/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.030675 - l_rec1:0.014625 - l_rec2:0.008025
#
# ssim: 0.639802 - psnr: 27.389967
#
# Epoch:256/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.029342 - l_rec1:0.014115 - l_rec2:0.007614
#
# ssim: 0.637012 - psnr: 27.365063
#
# Epoch:257/1000
# 31/31 [████████████████████] 4.70s  - train_loss:0.031426 - l_rec1:0.014969 - l_rec2:0.008229
#
# ssim: 0.661941 - psnr: 27.890980
#
# Epoch:258/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.028195 - l_rec1:0.013188 - l_rec2:0.007503
#
# ssim: 0.619928 - psnr: 26.960957
#
# Epoch:259/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.024678 - l_rec1:0.011983 - l_rec2:0.006348
#
# save_model ssim: 0.689388 - psnr: 28.480253
#
# Epoch:260/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.030056 - l_rec1:0.014582 - l_rec2:0.007737
#
# ssim: 0.671022 - psnr: 28.144690
#
# Epoch:261/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.033302 - l_rec1:0.015821 - l_rec2:0.008741
#
# ssim: 0.640902 - psnr: 27.431669
#
# Epoch:262/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.022409 - l_rec1:0.010351 - l_rec2:0.006029
#
# ssim: 0.668186 - psnr: 28.060619
#
# Epoch:263/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.025608 - l_rec1:0.011852 - l_rec2:0.006878
#
# ssim: 0.663607 - psnr: 27.945927
#
# Epoch:264/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.031392 - l_rec1:0.014635 - l_rec2:0.008378
#
# ssim: 0.641506 - psnr: 27.463974
#
# Epoch:265/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.036367 - l_rec1:0.017106 - l_rec2:0.009631
#
# ssim: 0.629874 - psnr: 27.194387
#
# Epoch:266/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.029396 - l_rec1:0.013696 - l_rec2:0.007850
#
# ssim: 0.629957 - psnr: 27.159525
#
# Epoch:267/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.031440 - l_rec1:0.014773 - l_rec2:0.008333
#
# ssim: 0.649736 - psnr: 27.564842
#
# Epoch:268/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.031153 - l_rec1:0.014852 - l_rec2:0.008150
#
# ssim: 0.657340 - psnr: 27.781466
#
# Epoch:269/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.023485 - l_rec1:0.010998 - l_rec2:0.006243
#
# ssim: 0.622358 - psnr: 27.001518
#
# Epoch:270/1000
# 31/31 [████████████████████] 4.68s  - train_loss:0.030229 - l_rec1:0.013915 - l_rec2:0.008157
#
# ssim: 0.660229 - psnr: 27.887772
#
# Epoch:271/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.028578 - l_rec1:0.013494 - l_rec2:0.007542
#
# ssim: 0.650583 - psnr: 27.625587
#
# Epoch:272/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.027519 - l_rec1:0.012658 - l_rec2:0.007431
#
# ssim: 0.637354 - psnr: 27.405416
#
# Epoch:273/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.030689 - l_rec1:0.014476 - l_rec2:0.008107
#
# ssim: 0.654648 - psnr: 27.713737
#
# Epoch:274/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.025800 - l_rec1:0.011613 - l_rec2:0.007094
#
# ssim: 0.642780 - psnr: 27.476908
#
# Epoch:275/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.038527 - l_rec1:0.017618 - l_rec2:0.010455
#
# ssim: 0.636755 - psnr: 27.280207
#
# Epoch:276/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.025673 - l_rec1:0.011751 - l_rec2:0.006961
#
# ssim: 0.637899 - psnr: 27.433167
#
# Epoch:277/1000
# 31/31 [████████████████████] 4.69s  - train_loss:0.029626 - l_rec1:0.013663 - l_rec2:0.007981
#
# ssim: 0.670328 - psnr: 28.151768
#
# Epoch:278/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.023560 - l_rec1:0.010653 - l_rec2:0.006454
#
# ssim: 0.633319 - psnr: 27.300415
#
# Epoch:279/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.033137 - l_rec1:0.014841 - l_rec2:0.009148
#
# ssim: 0.643910 - psnr: 27.523264
#
# Epoch:280/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.039319 - l_rec1:0.017764 - l_rec2:0.010778
#
# ssim: 0.641181 - psnr: 27.399652
#
# Epoch:281/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.036352 - l_rec1:0.016647 - l_rec2:0.009852
#
# ssim: 0.644915 - psnr: 27.544500
#
# Epoch:282/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.036427 - l_rec1:0.016747 - l_rec2:0.009840
#
# ssim: 0.659714 - psnr: 27.786581
#
# Epoch:283/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.034260 - l_rec1:0.015610 - l_rec2:0.009325
#
# ssim: 0.644065 - psnr: 27.484453
#
# Epoch:284/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.034230 - l_rec1:0.015665 - l_rec2:0.009283
#
# ssim: 0.653480 - psnr: 27.627312
#
# Epoch:285/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.038101 - l_rec1:0.017612 - l_rec2:0.010245
#
# ssim: 0.651695 - psnr: 27.583540
#
# Epoch:286/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.031260 - l_rec1:0.014166 - l_rec2:0.008547
#
# ssim: 0.642412 - psnr: 27.425596
#
# Epoch:287/1000
# 31/31 [████████████████████] 4.70s  - train_loss:0.031446 - l_rec1:0.014457 - l_rec2:0.008495
#
# ssim: 0.647512 - psnr: 27.550104
#
# Epoch:288/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.037930 - l_rec1:0.017223 - l_rec2:0.010353
#
# ssim: 0.654745 - psnr: 27.711296
#
# Epoch:289/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.036607 - l_rec1:0.016596 - l_rec2:0.010005
#
# ssim: 0.652381 - psnr: 27.656822
#
# Epoch:290/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.027773 - l_rec1:0.012601 - l_rec2:0.007586
#
# ssim: 0.625278 - psnr: 27.073414
#
# Epoch:291/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.037487 - l_rec1:0.017079 - l_rec2:0.010204
#
# ssim: 0.663628 - psnr: 27.872786
#
# Epoch:292/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.035901 - l_rec1:0.016104 - l_rec2:0.009899
#
# ssim: 0.651346 - psnr: 27.582430
#
# Epoch:293/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.038661 - l_rec1:0.017232 - l_rec2:0.010714
#
# ssim: 0.650837 - psnr: 27.639702
#
# Epoch:294/1000
# 31/31 [████████████████████] 4.71s  - train_loss:0.030654 - l_rec1:0.013698 - l_rec2:0.008478
#
# ssim: 0.667404 - psnr: 27.994175
#
# Epoch:295/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.034200 - l_rec1:0.015111 - l_rec2:0.009544
#
# ssim: 0.657627 - psnr: 27.767408
#
# Epoch:296/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.032768 - l_rec1:0.014390 - l_rec2:0.009189
#
# ssim: 0.652004 - psnr: 27.699196
#
# Epoch:297/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.032765 - l_rec1:0.014550 - l_rec2:0.009108
#
# ssim: 0.661128 - psnr: 27.909533
#
# Epoch:298/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.037207 - l_rec1:0.016741 - l_rec2:0.010233
#
# ssim: 0.631497 - psnr: 27.181078
#
# Epoch:299/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.035599 - l_rec1:0.015749 - l_rec2:0.009925
#
# ssim: 0.638759 - psnr: 27.339024
#
# Epoch:300/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.032015 - l_rec1:0.014063 - l_rec2:0.008976
#
# ssim: 0.637667 - psnr: 27.349487
#
# Epoch:301/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.035853 - l_rec1:0.015397 - l_rec2:0.010228
#
# ssim: 0.650846 - psnr: 27.672039
#
# Epoch:302/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.036651 - l_rec1:0.015924 - l_rec2:0.010363
#
# ssim: 0.651764 - psnr: 27.686485
#
# Epoch:303/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.033741 - l_rec1:0.014692 - l_rec2:0.009525
#
# ssim: 0.640179 - psnr: 27.414030
#
# Epoch:304/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.030857 - l_rec1:0.013179 - l_rec2:0.008839
#
# ssim: 0.643126 - psnr: 27.495687
#
# Epoch:305/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.032286 - l_rec1:0.014006 - l_rec2:0.009140
#
# ssim: 0.656874 - psnr: 27.783684
#
# Epoch:306/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.031667 - l_rec1:0.013888 - l_rec2:0.008889
#
# ssim: 0.636133 - psnr: 27.276960
#
# Epoch:307/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.035225 - l_rec1:0.014959 - l_rec2:0.010133
#
# ssim: 0.641952 - psnr: 27.475195
#
# Epoch:308/1000
# 31/31 [████████████████████] 4.68s  - train_loss:0.031397 - l_rec1:0.013530 - l_rec2:0.008934
#
# ssim: 0.667813 - psnr: 28.011747
#
# Epoch:309/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.035683 - l_rec1:0.015323 - l_rec2:0.010180
#
# ssim: 0.635300 - psnr: 27.205954
#
# Epoch:310/1000
# 31/31 [████████████████████] 4.53s  - train_loss:0.030344 - l_rec1:0.013206 - l_rec2:0.008569
#
# ssim: 0.649516 - psnr: 27.538790
#
# Epoch:311/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.039793 - l_rec1:0.016817 - l_rec2:0.011488
#
# ssim: 0.660965 - psnr: 27.851078
#
# Epoch:312/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.037074 - l_rec1:0.016140 - l_rec2:0.010467
#
# ssim: 0.631862 - psnr: 27.186975
#
# Epoch:313/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.034507 - l_rec1:0.014991 - l_rec2:0.009758
#
# ssim: 0.646842 - psnr: 27.540190
#
# Epoch:314/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.039800 - l_rec1:0.017025 - l_rec2:0.011387
#
# ssim: 0.636125 - psnr: 27.265539
#
# Epoch:315/1000
# 31/31 [████████████████████] 4.72s  - train_loss:0.035736 - l_rec1:0.015218 - l_rec2:0.010259
#
# ssim: 0.644946 - psnr: 27.514824
#
# Epoch:316/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.038287 - l_rec1:0.016491 - l_rec2:0.010898
#
# ssim: 0.648450 - psnr: 27.588829
#
# Epoch:317/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.035845 - l_rec1:0.015254 - l_rec2:0.010295
#
# ssim: 0.651524 - psnr: 27.632339
#
# Epoch:318/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.038531 - l_rec1:0.016372 - l_rec2:0.011079
#
# ssim: 0.632775 - psnr: 27.237724
#
# Epoch:319/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.030560 - l_rec1:0.013263 - l_rec2:0.008649
#
# ssim: 0.652854 - psnr: 27.658186
#
# Epoch:320/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.033245 - l_rec1:0.013999 - l_rec2:0.009623
#
# ssim: 0.626647 - psnr: 27.054695
#
# Epoch:321/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.035966 - l_rec1:0.015045 - l_rec2:0.010461
#
# ssim: 0.667882 - psnr: 27.912014
#
# Epoch:322/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.032610 - l_rec1:0.013804 - l_rec2:0.009403
#
# ssim: 0.670634 - psnr: 28.031218
#
# Epoch:323/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.037181 - l_rec1:0.015587 - l_rec2:0.010797
#
# ssim: 0.659781 - psnr: 27.757666
#
# Epoch:324/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.037962 - l_rec1:0.016168 - l_rec2:0.010897
#
# ssim: 0.640458 - psnr: 27.391466
#
# Epoch:325/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.033444 - l_rec1:0.014156 - l_rec2:0.009644
#
# ssim: 0.651280 - psnr: 27.677187
#
# Epoch:326/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.040923 - l_rec1:0.017115 - l_rec2:0.011904
#
# ssim: 0.651295 - psnr: 27.616484
#
# Epoch:327/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.031296 - l_rec1:0.013053 - l_rec2:0.009121
#
# ssim: 0.669177 - psnr: 28.034649
#
# Epoch:328/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.037801 - l_rec1:0.015936 - l_rec2:0.010933
#
# ssim: 0.640114 - psnr: 27.423140
#
# Epoch:329/1000
# 31/31 [████████████████████] 4.69s  - train_loss:0.033828 - l_rec1:0.014009 - l_rec2:0.009910
#
# ssim: 0.660677 - psnr: 27.850863
#
# Epoch:330/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.036245 - l_rec1:0.015070 - l_rec2:0.010587
#
# ssim: 0.626999 - psnr: 27.141644
#
# Epoch:331/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.032435 - l_rec1:0.013438 - l_rec2:0.009499
#
# ssim: 0.643578 - psnr: 27.478447
#
# Epoch:332/1000
# ...
#
# Epoch:890/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.073350 - l_rec1:0.015822 - l_rec2:0.028764
#
# ssim: 0.661678 - psnr: 27.811996
#
# Epoch:891/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.071576 - l_rec1:0.014864 - l_rec2:0.028356
#
# ssim: 0.657200 - psnr: 27.813414
#
# Epoch:892/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.065444 - l_rec1:0.013758 - l_rec2:0.025843
#
# ssim: 0.665852 - psnr: 27.996998
#
# Epoch:893/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.077815 - l_rec1:0.016108 - l_rec2:0.030853
#
# ssim: 0.645108 - psnr: 27.458971
#
# Epoch:894/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.059250 - l_rec1:0.012068 - l_rec2:0.023591
#
# ssim: 0.664863 - psnr: 27.915424
#
# Epoch:895/1000
# 31/31 [████████████████████] 4.69s  - train_loss:0.069851 - l_rec1:0.014565 - l_rec2:0.027643
#
# ssim: 0.663311 - psnr: 27.924656
#
# Epoch:896/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.066939 - l_rec1:0.013630 - l_rec2:0.026655
#
# ssim: 0.655754 - psnr: 27.758398
#
# Epoch:897/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.071511 - l_rec1:0.015127 - l_rec2:0.028192
#
# ssim: 0.662435 - psnr: 27.872145
#
# Epoch:898/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.067825 - l_rec1:0.013928 - l_rec2:0.026949
#
# ssim: 0.646355 - psnr: 27.547779
#
# Epoch:899/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.064714 - l_rec1:0.013531 - l_rec2:0.025591
#
# ssim: 0.683351 - psnr: 28.372206
#
# Epoch:900/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.076739 - l_rec1:0.016056 - l_rec2:0.030341
#
# ssim: 0.648857 - psnr: 27.597307
#
# Epoch:901/1000
# 31/31 [████████████████████] 4.65s  - train_loss:0.062991 - l_rec1:0.012999 - l_rec2:0.024996
#
# ssim: 0.670181 - psnr: 28.035105
#
# Epoch:902/1000
# 31/31 [████████████████████] 4.70s  - train_loss:0.064632 - l_rec1:0.013185 - l_rec2:0.025723
#
# ssim: 0.657882 - psnr: 27.764187
#
# Epoch:903/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.080531 - l_rec1:0.016736 - l_rec2:0.031898
#
# ssim: 0.647255 - psnr: 27.562756
#
# Epoch:904/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.060667 - l_rec1:0.012001 - l_rec2:0.024333
#
# ssim: 0.644715 - psnr: 27.499887
#
# Epoch:905/1000
# 31/31 [████████████████████] 4.65s  - train_loss:0.064793 - l_rec1:0.013591 - l_rec2:0.025601
#
# ssim: 0.646227 - psnr: 27.478958
#
# Epoch:906/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.066355 - l_rec1:0.013643 - l_rec2:0.026356
#
# ssim: 0.656790 - psnr: 27.777617
#
# Epoch:907/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.060474 - l_rec1:0.012079 - l_rec2:0.024197
#
# ssim: 0.650736 - psnr: 27.605038
#
# Epoch:908/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.056618 - l_rec1:0.011338 - l_rec2:0.022640
#
# ssim: 0.658562 - psnr: 27.817684
#
# Epoch:909/1000
# 31/31 [████████████████████] 4.76s  - train_loss:0.071417 - l_rec1:0.014816 - l_rec2:0.028301
#
# ssim: 0.649074 - psnr: 27.537533
#
# Epoch:910/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.066648 - l_rec1:0.013789 - l_rec2:0.026430
#
# ssim: 0.651196 - psnr: 27.634575
#
# Epoch:911/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.058488 - l_rec1:0.012189 - l_rec2:0.023149
#
# ssim: 0.641093 - psnr: 27.405573
#
# Epoch:912/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.073641 - l_rec1:0.015325 - l_rec2:0.029158
#
# ssim: 0.632574 - psnr: 27.184393
#
# Epoch:913/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.060900 - l_rec1:0.012477 - l_rec2:0.024211
#
# ssim: 0.655442 - psnr: 27.740896
#
# Epoch:914/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.072070 - l_rec1:0.014741 - l_rec2:0.028664
#
# ssim: 0.660006 - psnr: 27.830626
#
# Epoch:915/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.069599 - l_rec1:0.014057 - l_rec2:0.027771
#
# ssim: 0.665649 - psnr: 27.971508
#
# Epoch:916/1000
# 31/31 [████████████████████] 4.75s  - train_loss:0.082546 - l_rec1:0.016573 - l_rec2:0.032986
#
# ssim: 0.657678 - psnr: 27.776022
#
# Epoch:917/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.082150 - l_rec1:0.017161 - l_rec2:0.032495
#
# ssim: 0.671783 - psnr: 28.061987
#
# Epoch:918/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.072011 - l_rec1:0.014840 - l_rec2:0.028586
#
# ssim: 0.671074 - psnr: 28.113522
#
# Epoch:919/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.071077 - l_rec1:0.014482 - l_rec2:0.028298
#
# ssim: 0.652780 - psnr: 27.712185
#
# Epoch:920/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.063305 - l_rec1:0.012876 - l_rec2:0.025214
#
# ssim: 0.664324 - psnr: 27.895969
#
# Epoch:921/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.087248 - l_rec1:0.017939 - l_rec2:0.034654
#
# ssim: 0.650204 - psnr: 27.598942
#
# Epoch:922/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.064496 - l_rec1:0.012937 - l_rec2:0.025779
#
# ssim: 0.682351 - psnr: 28.368570
#
# Epoch:923/1000
# 31/31 [████████████████████] 4.71s  - train_loss:0.076715 - l_rec1:0.015322 - l_rec2:0.030696
#
# ssim: 0.660371 - psnr: 27.819462
#
# Epoch:924/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.082559 - l_rec1:0.017225 - l_rec2:0.032667
#
# ssim: 0.682579 - psnr: 28.339790
#
# Epoch:925/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.079422 - l_rec1:0.016182 - l_rec2:0.031620
#
# ssim: 0.654069 - psnr: 27.691292
#
# Epoch:926/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.061757 - l_rec1:0.012340 - l_rec2:0.024709
#
# ssim: 0.633868 - psnr: 27.269264
#
# Epoch:927/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.074755 - l_rec1:0.015330 - l_rec2:0.029712
#
# ssim: 0.653902 - psnr: 27.615892
#
# Epoch:928/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.068107 - l_rec1:0.014092 - l_rec2:0.027008
#
# ssim: 0.655297 - psnr: 27.736658
#
# Epoch:929/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.065878 - l_rec1:0.013461 - l_rec2:0.026209
#
# ssim: 0.652562 - psnr: 27.661289
#
# Epoch:930/1000
# 31/31 [████████████████████] 4.70s  - train_loss:0.067803 - l_rec1:0.013857 - l_rec2:0.026973
#
# ssim: 0.667122 - psnr: 28.026533
#
# Epoch:931/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.070976 - l_rec1:0.013896 - l_rec2:0.028540
#
# ssim: 0.654823 - psnr: 27.734261
#
# Epoch:932/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.071476 - l_rec1:0.014167 - l_rec2:0.028654
#
# ssim: 0.668184 - psnr: 28.016907
#
# Epoch:933/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.070441 - l_rec1:0.013834 - l_rec2:0.028303
#
# ssim: 0.669411 - psnr: 28.030886
#
# Epoch:934/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.063892 - l_rec1:0.012922 - l_rec2:0.025485
#
# ssim: 0.650647 - psnr: 27.625988
#
# Epoch:935/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.066312 - l_rec1:0.013413 - l_rec2:0.026449
#
# ssim: 0.678512 - psnr: 28.235086
#
# Epoch:936/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.068457 - l_rec1:0.013735 - l_rec2:0.027361
#
# ssim: 0.645986 - psnr: 27.513975
#
# Epoch:937/1000
# 31/31 [████████████████████] 4.72s  - train_loss:0.066411 - l_rec1:0.013383 - l_rec2:0.026514
#
# ssim: 0.669353 - psnr: 28.019566
#
# Epoch:938/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.064197 - l_rec1:0.012381 - l_rec2:0.025908
#
# ssim: 0.648886 - psnr: 27.553740
#
# Epoch:939/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.063092 - l_rec1:0.012587 - l_rec2:0.025253
#
# ssim: 0.653157 - psnr: 27.693161
#
# Epoch:940/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.072973 - l_rec1:0.014413 - l_rec2:0.029280
#
# ssim: 0.630900 - psnr: 27.145411
#
# Epoch:941/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.077019 - l_rec1:0.015701 - l_rec2:0.030659
#
# ssim: 0.653852 - psnr: 27.677727
#
# Epoch:942/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.087881 - l_rec1:0.017668 - l_rec2:0.035107
#
# ssim: 0.667809 - psnr: 27.982492
#
# Epoch:943/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.075737 - l_rec1:0.014970 - l_rec2:0.030384
#
# ssim: 0.654839 - psnr: 27.684341
#
# Epoch:944/1000
# 31/31 [████████████████████] 4.67s  - train_loss:0.070074 - l_rec1:0.013310 - l_rec2:0.028382
#
# ssim: 0.647539 - psnr: 27.559919
#
# Epoch:945/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.076336 - l_rec1:0.015470 - l_rec2:0.030433
#
# ssim: 0.644369 - psnr: 27.501612
#
# Epoch:946/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.074809 - l_rec1:0.015079 - l_rec2:0.029865
#
# ssim: 0.680485 - psnr: 28.284092
#
# Epoch:947/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.065858 - l_rec1:0.012955 - l_rec2:0.026452
#
# ssim: 0.661320 - psnr: 27.839567
#
# Epoch:948/1000
# 31/31 [████████████████████] 4.64s  - train_loss:0.088174 - l_rec1:0.018091 - l_rec2:0.035041
#
# ssim: 0.644310 - psnr: 27.405783
#
# Epoch:949/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.075803 - l_rec1:0.014490 - l_rec2:0.030656
#
# ssim: 0.654019 - psnr: 27.676805
#
# Epoch:950/1000
# 31/31 [████████████████████] 4.74s  - train_loss:0.064900 - l_rec1:0.013044 - l_rec2:0.025928
#
# ssim: 0.636145 - psnr: 27.269442
#
# Epoch:951/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.076784 - l_rec1:0.015099 - l_rec2:0.030842
#
# ssim: 0.666233 - psnr: 27.946163
#
# Epoch:952/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.078918 - l_rec1:0.015347 - l_rec2:0.031786
#
# ssim: 0.625967 - psnr: 27.057425
#
# Epoch:953/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.075453 - l_rec1:0.015056 - l_rec2:0.030199
#
# ssim: 0.652439 - psnr: 27.609898
#
# Epoch:954/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.060159 - l_rec1:0.011830 - l_rec2:0.024165
#
# ssim: 0.672238 - psnr: 28.128756
#
# Epoch:955/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.063736 - l_rec1:0.012554 - l_rec2:0.025591
#
# ssim: 0.651279 - psnr: 27.651699
#
# Epoch:956/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.070008 - l_rec1:0.013887 - l_rec2:0.028061
#
# ssim: 0.653773 - psnr: 27.705481
#
# Epoch:957/1000
# 31/31 [████████████████████] 4.71s  - train_loss:0.064239 - l_rec1:0.012860 - l_rec2:0.025689
#
# ssim: 0.652467 - psnr: 27.653271
#
# Epoch:958/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.075015 - l_rec1:0.015259 - l_rec2:0.029878
#
# ssim: 0.679762 - psnr: 28.239920
#
# Epoch:959/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.070663 - l_rec1:0.014122 - l_rec2:0.028271
#
# ssim: 0.653787 - psnr: 27.685442
#
# Epoch:960/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.084423 - l_rec1:0.016563 - l_rec2:0.033930
#
# ssim: 0.677254 - psnr: 28.215488
#
# Epoch:961/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.066456 - l_rec1:0.013510 - l_rec2:0.026473
#
# save_model ssim: 0.690204 - psnr: 28.505947
#
# Epoch:962/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.070265 - l_rec1:0.013576 - l_rec2:0.028345
#
# ssim: 0.648896 - psnr: 27.546581
#
# Epoch:963/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.065477 - l_rec1:0.012940 - l_rec2:0.026268
#
# ssim: 0.654307 - psnr: 27.735582
#
# Epoch:964/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.068164 - l_rec1:0.013815 - l_rec2:0.027175
#
# ssim: 0.637072 - psnr: 27.268345
#
# Epoch:965/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.070601 - l_rec1:0.013845 - l_rec2:0.028378
#
# ssim: 0.661865 - psnr: 27.828938
#
# Epoch:966/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.077461 - l_rec1:0.014933 - l_rec2:0.031264
#
# ssim: 0.643206 - psnr: 27.459736
#
# Epoch:967/1000
# 31/31 [████████████████████] 4.70s  - train_loss:0.078009 - l_rec1:0.015278 - l_rec2:0.031365
#
# ssim: 0.659592 - psnr: 27.815334
#
# Epoch:968/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.079256 - l_rec1:0.015579 - l_rec2:0.031839
#
# ssim: 0.662081 - psnr: 27.884798
#
# Epoch:969/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.065040 - l_rec1:0.012538 - l_rec2:0.026251
#
# ssim: 0.663122 - psnr: 27.900446
#
# Epoch:970/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.075846 - l_rec1:0.014856 - l_rec2:0.030495
#
# ssim: 0.652433 - psnr: 27.670357
#
# Epoch:971/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.069128 - l_rec1:0.013415 - l_rec2:0.027857
#
# ssim: 0.658930 - psnr: 27.827148
#
# Epoch:972/1000
# 31/31 [████████████████████] 4.63s  - train_loss:0.072885 - l_rec1:0.014685 - l_rec2:0.029100
#
# ssim: 0.667246 - psnr: 27.937782
#
# Epoch:973/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.078936 - l_rec1:0.015472 - l_rec2:0.031732
#
# ssim: 0.664620 - psnr: 27.969439
#
# Epoch:974/1000
# 31/31 [████████████████████] 4.69s  - train_loss:0.068290 - l_rec1:0.013349 - l_rec2:0.027471
#
# ssim: 0.661143 - psnr: 27.874609
#
# Epoch:975/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.070117 - l_rec1:0.013544 - l_rec2:0.028286
#
# ssim: 0.652803 - psnr: 27.642002
#
# Epoch:976/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.077490 - l_rec1:0.015025 - l_rec2:0.031233
#
# ssim: 0.669065 - psnr: 28.044077
#
# Epoch:977/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.069229 - l_rec1:0.013574 - l_rec2:0.027827
#
# ssim: 0.663045 - psnr: 27.945070
#
# Epoch:978/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.074958 - l_rec1:0.014894 - l_rec2:0.030032
#
# ssim: 0.660133 - psnr: 27.875473
#
# Epoch:979/1000
# 31/31 [████████████████████] 4.62s  - train_loss:0.076954 - l_rec1:0.014610 - l_rec2:0.031172
#
# ssim: 0.657784 - psnr: 27.791708
#
# Epoch:980/1000
# 31/31 [████████████████████] 4.66s  - train_loss:0.075675 - l_rec1:0.014403 - l_rec2:0.030636
#
# ssim: 0.662441 - psnr: 27.894537
#
# Epoch:981/1000
# 31/31 [████████████████████] 4.67s  - train_loss:0.075853 - l_rec1:0.015113 - l_rec2:0.030370
#
# ssim: 0.627631 - psnr: 27.093596
#
# Epoch:982/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.063500 - l_rec1:0.012200 - l_rec2:0.025650
#
# ssim: 0.662664 - psnr: 27.951431
#
# Epoch:983/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.068700 - l_rec1:0.013092 - l_rec2:0.027804
#
# ssim: 0.653426 - psnr: 27.661695
#
# Epoch:984/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.066553 - l_rec1:0.012452 - l_rec2:0.027051
#
# ssim: 0.687210 - psnr: 28.447660
#
# Epoch:985/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.070195 - l_rec1:0.013546 - l_rec2:0.028325
#
# ssim: 0.664057 - psnr: 27.949383
#
# Epoch:986/1000
# 31/31 [████████████████████] 4.56s  - train_loss:0.083694 - l_rec1:0.016409 - l_rec2:0.033643
#
# ssim: 0.647121 - psnr: 27.512356
#
# Epoch:987/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.077864 - l_rec1:0.015023 - l_rec2:0.031420
#
# ssim: 0.643518 - psnr: 27.439463
#
# Epoch:988/1000
# 31/31 [████████████████████] 4.72s  - train_loss:0.056345 - l_rec1:0.010605 - l_rec2:0.022870
#
# ssim: 0.651597 - psnr: 27.576660
#
# Epoch:989/1000
# 31/31 [████████████████████] 4.60s  - train_loss:0.067719 - l_rec1:0.013122 - l_rec2:0.027298
#
# ssim: 0.679253 - psnr: 28.300486
#
# Epoch:990/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.075068 - l_rec1:0.014179 - l_rec2:0.030445
#
# ssim: 0.662884 - psnr: 27.907770
#
# Epoch:991/1000
# 31/31 [████████████████████] 4.55s  - train_loss:0.081500 - l_rec1:0.015760 - l_rec2:0.032870
#
# ssim: 0.662084 - psnr: 27.872456
#
# Epoch:992/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.071711 - l_rec1:0.013933 - l_rec2:0.028889
#
# ssim: 0.650401 - psnr: 27.549614
#
# Epoch:993/1000
# 31/31 [████████████████████] 4.58s  - train_loss:0.081130 - l_rec1:0.016062 - l_rec2:0.032534
#
# ssim: 0.670462 - psnr: 28.062792
#
# Epoch:994/1000
# 31/31 [████████████████████] 4.61s  - train_loss:0.081734 - l_rec1:0.015350 - l_rec2:0.033192
#
# ssim: 0.678615 - psnr: 28.207167
#
# Epoch:995/1000
# 31/31 [████████████████████] 4.68s  - train_loss:0.077214 - l_rec1:0.014954 - l_rec2:0.031130
#
# ssim: 0.646285 - psnr: 27.559444
#
# Epoch:996/1000
# 31/31 [████████████████████] 4.57s  - train_loss:0.081635 - l_rec1:0.015927 - l_rec2:0.032854
#
# ssim: 0.661189 - psnr: 27.828707
#
# Epoch:997/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.062732 - l_rec1:0.012046 - l_rec2:0.025343
#
# ssim: 0.658646 - psnr: 27.800961
#
# Epoch:998/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.076646 - l_rec1:0.014721 - l_rec2:0.030962
#
# ssim: 0.658732 - psnr: 27.778505
#
# Epoch:999/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.065541 - l_rec1:0.012436 - l_rec2:0.026553
#
# ssim: 0.652366 - psnr: 27.613363
#
# Epoch:1000/1000
# 31/31 [████████████████████] 4.59s  - train_loss:0.068301 - l_rec1:0.012483 - l_rec2:0.027909
#
# ssim: 0.653894 - psnr: 27.746572

# %%
model.save_weights(model_path + model_name + '/weights/finish/')
